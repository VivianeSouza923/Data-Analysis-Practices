# %% [markdown]
# <a href="https://colab.research.google.com/github/VivianeSouza923/Data-Analysis-Practices/blob/main/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pegar a base direto lá no uci
# !pip install ucimlrepo

# %%
# importo a função fetch_ucirepo do módulo ucimlrepo
from ucimlrepo import fetch_ucirepo

# na variável iris, eu armazeno a minha busca pelo id=53 (que é o código do dataset da Iris). A funçãi fetch_ucirepo é responsável por isso.
iris = fetch_ucirepo(id=53)

# data (as pandas dataframes)
X = iris.data.features # na X, eu vou armazenar as features do df
y = iris.data.targets # na y, eu vou armazenar as targets do df

# metadata
print(iris.metadata)

# variable information
print(iris.variables)

# Descriptive statistics
print(X.describe())
# Out:
# {'uci_id': 53, 'name': 'Iris', 'repository_url': 'https://archive.ics.uci.edu/dataset/53/iris', 'data_url': 'https://archive.ics.uci.edu/static/public/53/data.csv', 'abstract': 'A small classic dataset from Fisher, 1936. One of the earliest known datasets used for evaluating classification methods.\n', 'area': 'Biology', 'tasks': ['Classification'], 'characteristics': ['Tabular'], 'num_instances': 150, 'num_features': 4, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1936, 'last_updated': 'Tue Sep 12 2023', 'dataset_doi': '10.24432/C56C76', 'creators': ['R. A. Fisher'], 'intro_paper': {'title': 'The Iris data set: In search of the source of virginica', 'authors': 'A. Unwin, K. Kleinman', 'published_in': 'Significance, 2021', 'year': 2021, 'url': 'https://www.semanticscholar.org/paper/4599862ea877863669a6a8e63a3c707a787d5d7e', 'doi': '1740-9713.01589'}, 'a
# ...

# %%
# Show ISIS
iris
# Out:
# {'data': {'ids': None,
#   'features':      sepal length  sepal width  petal length  petal width
#   0             5.1          3.5           1.4          0.2
#   1             4.9          3.0           1.4          0.2
#   2             4.7          3.2           1.3          0.2
#   3             4.6          3.1           1.5          0.2
#   4             5.0          3.6           1.4          0.2
#   ..            ...          ...           ...          ...
#   145           6.7          3.0           5.2          2.3
#   146           6.3          2.5           5.0          1.9
#   147           6.5          3.0           5.2          2.0
#   148           6.2          3.4           5.4          2.3
#   149           5.9          3.0           5.1          1.8
#
#   [150 rows x 4 columns],
#   'targets':               class
#   0       Iris-setosa
#   1       Iris-setosa
#   2       Iris-setosa
#   3       Iris-setosa
#   4       Iris-setosa
#   ..              ...
# ...

# %%
# show features
X
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
# Show Labels/targets
y
# Out:
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
# absolute frequency of each label
y.value_counts()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# I create a column called Target and populate it with the targets stored in Y. This column will be from the series of X (features)
X['Target']=y
X
# Out:
#      sepal length  sepal width  petal length  petal width          Target
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# I get a concise summary of the df information
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  150 non-null    float64
#  1   sepal width   150 non-null    float64
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
#  4   Target        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Import the library
import seaborn as sns

# Create a boxplot. The boxplot receives the following parameters: date (receives the dataframe);
# x: categorical variable (its name is enclosed in quotation marks);
# y: quantitative variable (its name is enclosed in quotation marks) and color:'color_name'
# the box height (boxplot) is defined by the interquartile range(IQR), which is the difference between Q3 and Q1
# THE MIDDLE LINE REPRESENTS THE MEDIAN OF THE SEPAL LENGTHS FOR EACH CLASS.
# Values other than whiskers are considered atypical, outliers
sns.boxplot(data=X, x="Target", y="sepal length", color='navy')
# Out:
# <Axes: xlabel='Target', ylabel='sepal length'>

# %%
#sepal width 	petal length 	petal width
sns.boxplot(data=X, x="Target", y="sepal width", color='blue')
# Out:
# <Axes: xlabel='Target', ylabel='sepal width'>

# %%
#sepal width 	petal length 	petal width
sns.boxplot(data=X, x="Target", y="petal length", color='green')
# Out:
# <Axes: xlabel='Target', ylabel='petal length'>

# %%
#sepal width 	petal length 	petal width
sns.boxplot(data=X, x="Target", y="petal width", color='red')
# Out:
# <Axes: xlabel='Target', ylabel='petal width'>

# %%
# I import the Statsmodels library, which is used for statistical modeling.
import statsmodels.api as sm
# I import the ols (Ordinary Least Squares) function from the Statsmodels formula API, which allows you to create regression models using R-style formulas.
from statsmodels.formula.api import ols
# The code creates regression models for each quantitative variable as a function of the categorical variable Target.

# Model for Sepal Length
# the ols function of the statsmodels.formula.api module allows me to use formulas in the R language style
# this Q is a function that ensures that the column name is interpreted correctly by the formula,
# regardless of whether it contains spaces or special characters.
# The C() function indicates that Target is a categorical variable.
# THE OLS FUNCTION STILL RECEIVES A PARAMETER CALLED DATA, WHICH RECEIVES THE DF
# THE FIT FUNCTION ADJUSTS THE MODEL TO THE DATA
modelo = ols('Q("sepal length") ~ C(Q("Target"))', data=X).fit()

# R2 CALCULATION - It's the number that tells us how well the regression model is explaining the data we have
# the modelo.rsquared extracts the coefficient of determination from the fitted model (R²) which indicates the proportion of the variability of the dependent
# variable explained by the model
# the R² ranges from 0 to 1, where 0 is: the regression model could not explain any of the data; 1: The model was able to explain 100% of the data and between
# 0 and 1: The model was able to explain part of the data.
r_squared = modelo.rsquared

# view R²
print("Coeficiente de determinação (R^2):", r_squared)

#  Regression Model for Sepal width
modelo = ols('Q("sepal width") ~ C(Q("Target"))', data=X).fit()

# R2 CALCULATION for sepal width
r_squared = modelo.rsquared
# view R²
print("Coeficiente de determinação (R^2):", r_squared)

# Regression Model for petal length
modelo = ols('Q("petal length") ~ C(Q("Target"))', data=X).fit()

# R2 CALCULATION for petal length
r_squared = modelo.rsquared

# view R²
print("Coeficiente de determinação (R^2):", r_squared)


#  Regression Model for petal width
modelo = ols('Q("petal width") ~ C(Q("Target"))', data=X).fit()

# R2 CALCULATION for petal width
r_squared = modelo.rsquared

# view R²
print("Coeficiente de determinação (R^2):", r_squared)
# Out:
# Coeficiente de determinação (R^2): 0.6187057307384871
# Coeficiente de determinação (R^2): 0.39188079649871865
# Coeficiente de determinação (R^2): 0.9413189735606261
# Coeficiente de determinação (R^2): 0.9288359186784011

# %%
import pandas as pd # import the library
import matplotlib.pyplot as plt

X_without_target = X.drop(columns=['Target']) # I remove the column from the labels

# Correlation Matrix Calculation
matriz_correlacao = X_without_target.corr() # correlation coefficient, also known as Pearson's correlation coefficient
sns.heatmap(matriz_correlacao, annot=True, cmap='RdYlBu')
plt.title('Matriz de Correlação') # heatmap title
plt.show() # show heatmap

print()  # skip the line


# View Correlation Matrix
print(matriz_correlacao)

# 1 or closer to 1: perfect positive correlation, i.e., as one variable increases, the other also increases, in a linear fashion
# -1 or closer to -1: perfect negative correlation, i.e., as one variable increases, the other variable decreases linearly
# 0: no linear correlation
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# # Which variable is least relevant to distinguishing between different flower species?

# %% [markdown]
# # As três celulas a seguir são a plotagem de sepal width com todas as outras medidas.

# %%
import pandas as pd # import the library
import matplotlib.pyplot as plt # import the library

categorias=['Iris-setosa', 'Iris-versicolor','Iris-virginica'] # List containing the 3 categories of flowers in the dataset
cores = {'Iris-setosa': 'cyan', 'Iris-versicolor': 'magenta', 'Iris-virginica': 'yellow'} # color dictionary, where the keys are the categories of flowers

# Create the scatter plot
for cat in set(X['Target']): # I scroll through each unique category in the labels column
    # And within that loop, I plot the scatter plot.
    # In this loop, I take all the values of the data in question that have the same cat category as the target category, i.e. I get the data to plot when the
    #categories hit
    plt.scatter(X.loc[X['Target'] == cat, 'sepal width'], # When the category of the Target column is the same as the category of the CAT, I plot the sepal length
                X.loc[X['Target'] == cat, 'petal width'], # When the category of the Target column is the same as the category of the CAT category, I plot the PETAL WIDTH
                c=cores[cat], label=cat, marker='.') # I set the color of the plot based on the current category (cat). I also define the label based on the current category (cat)

# Add labels and legend
plt.xlabel('sepal width') # label of x axis
plt.ylabel('petal width') # label of y axis
plt.title('Gráfico de Dispersão') # Chart Title
plt.legend() # Chart Legend

# Show the plot
plt.show()

# %% [markdown]
# ## Plotagem de petal length e sepal length

# %%
import pandas as pd # import the library
import matplotlib.pyplot as plt # import the library

categorias=['Iris-setosa', 'Iris-versicolor','Iris-virginica'] # List of Available Categories of Flowers
cores = {'Iris-setosa': 'black', 'Iris-versicolor': 'orange', 'Iris-virginica': 'purple'} # dictionary associating color, with the keys being the categories in the list in the previous line


for cat in set(X['Target']): # for each unique value within the set (which is populated by the target column of dataset X)
    plt.scatter(X.loc[X['Target'] == cat, 'petal length'], # If the category in question in the Target column is the same as the CAT category in question, I take the PETAL LENGTH to plot
                X.loc[X['Target'] == cat, 'sepal width'], # If the category in question from the Target column is the same as the category CAT in question, I take the Sepal Length to plot
                c=cores[cat], label=cat, marker=',') # I set the color of the plot based on the current category (cat). label will be given the name of the current category
                # I'm going to change the marker just to give it a little charm
# Add labels and legend
plt.xlabel('petal length') # x-axis label
plt.ylabel('sepal width') # y-axis label+
plt.title('Gráfico de Dispersão') # chart title
plt.legend() # chart legend

# show the plot
plt.show()

# %%
import pandas as pd # import the library
import matplotlib.pyplot as plt  # import the library
# Color mapping for each category
categorias=['Iris-setosa', 'Iris-versicolor','Iris-virginica'] # List of flower categories from the Iris dataset
cores = {'Iris-setosa': 'brown', 'Iris-versicolor': 'pink', 'Iris-virginica': 'gray'} # dictionary associating color, with the keys being the categories in the list in the previous line

# I create the scatter plot
for cat in set(X['Target']): # for each unique value within the set (which is populated by the target column of dataset X)
    plt.scatter(X.loc[X['Target'] == cat, 'sepal width'], # If the category in question in the Target column is the same as the CAT category in question, I take the PETAL LENGTH to plot
                X.loc[X['Target'] == cat, 'sepal length'], # If the category in question in the Target column is the same as the CAT category in question, I take the PETAL width to plot
                c=cores[cat], label=cat, marker='o') # I set the color of the plot based on the current category (cat). label will be given the name of the current category
                # I'm going to change the marker just to give it a little charm
# Add label and legends
plt.xlabel('sepal width') # x-axis label
plt.ylabel('sepal length') # y-axis label
plt.title('Gráfico de Dispersão') # chart title
plt.legend() # chart legend

# show the plot
plt.show()

# %% [markdown]
# # As duas celulas a seguir são a plotagem de sepal length com todas as outras medidas.

# %%
import pandas as pd # Import the library to manipulate and visualize data
import matplotlib.pyplot as plt # Import the library to create charts

# Color mapping for each category
categorias = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']  # List of flower categories from the Iris dataset
cores = {'Iris-setosa': 'olive', 'Iris-versicolor': 'teal', 'Iris-virginica': 'navy'}  # Dictionary associating color with the keys being the categories in the list in the previous line

# I create the scatter plot
for cat in set(X['Target']): # for each unique value within the set (which is populated by the target column of dataset X)
    plt.scatter(X.loc[X['Target'] == cat, 'sepal length'], # If the category in question in the Target column is the same as the CAT category in question, I take the sepal LENGTH to plot
                X.loc[X['Target'] == cat, 'petal width'], # If the category in question in the Target column is the same as the CAT category in question, I take the PETAL WIDTH to plot
                c=cores[cat], label=cat, marker='x') # I set the color of the plot based on the current category (cat). label will be given the name of the current category
                # I'm going to change the marker just to give it a little charm

# Add label and legends
plt.xlabel('sepal length') # x-axis label
plt.ylabel('petal width') # y-axis label
plt.title('Gráfico de Dispersão') # Chart title
plt.legend() # chart lehend

# shoiw tje plit
plt.show()

# %%
import pandas as pd # Import the library to manipulate and visualize data
import matplotlib.pyplot as plt # Import the library to create charts

# Color mapping for each category
categorias = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']  # List of flower categories from the Iris dataset
cores = {'Iris-setosa': 'blue', 'Iris-versicolor': 'green', 'Iris-virginica': 'red'}  # Dictionary associating color with the keys being the categories in the list in the previous line

# I create the scatter plot
for cat in set(X['Target']): # for each unique value within the set (which is populated by the target column of dataset X)
    plt.scatter(X.loc[X['Target'] == cat, 'sepal length'], # If the category in question in the Target column is the same as the CAT category in question, I take the sepal LENGTH to plot
                X.loc[X['Target'] == cat, 'petal length'], # If the category in question in the Target column is the same as the CAT category in question, I take the PETAL length to plot
                c=cores[cat], label=cat, marker='+') # I set the color of the plot based on the current category (cat). label will be given the name of the current category
                # I'm going to change the marker just to give it a little charm

# Add label and legends
plt.xlabel('sepal length') # x-axis label
plt.ylabel('petal length') # y-axis label
plt.title('Gráfico de Dispersão') # Chart title
plt.legend() # chart lehend

# shoiw tje plit
plt.show()

# %% [markdown]
# # plotagem de petal length com a petal width.

# %%
import pandas as pd # Import the library to manipulate and visualize data
import matplotlib.pyplot as plt # Import the library to create charts

# Color mapping for each category
categorias = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']  # List of flower categories from the Iris dataset
cores = {'Iris-setosa': 'cyan', 'Iris-versicolor': 'magenta', 'Iris-virginica': 'yellow'}  # Dictionary associating color with the keys being the categories in the list in the previous line

# I create the scatter plot
for cat in set(X['Target']): # for each unique value within the set (which is populated by the target column of dataset X)
    plt.scatter(X.loc[X['Target'] == cat, 'petal length'], # If the category in question in the Target column is the same as the CAT category in question, I take the petal LENGTH to plot
                X.loc[X['Target'] == cat, 'petal width'], # If the category in question in the Target column is the same as the CAT category in question, I take the PETAL widdddth to plot
                c=cores[cat], label=cat, marker='_') # I set the color of the plot based on the current category (cat). label will be given the name of the current category
                # I'm going to change the marker just to give it a little charm

# Add label and legends
plt.xlabel('petal length') # x-axis label
plt.ylabel('petal width') # y-axis label
plt.title('Gráfico de Dispersão') # Chart title
plt.legend() # chart lehend

# shoiw tje plit
plt.show()

# %% [markdown]
# If I were to delete a variable, I would delete Sepal Width, visualizing the scatter plot.

# %%
import pandas as pd # Import the library to manipulate and visualize data
import matplotlib.pyplot as plt # Import the library to create charts
from mpl_toolkits.mplot3d import Axes3D # Import the package (mpl.toolkits) from this module (mplot3d) to create 3D graphics. we are importing the Axes3D class

# Color mapping for each category
categorias = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']  # List of flower categories from the Iris dataset
cores = {'Iris-setosa': 'black', 'Iris-versicolor': 'orange', 'Iris-virginica': 'purple'}  # Dictionary associating color with the keys being the categories in the list in the previous line



# create the 3D figure
fig = plt.figure(figsize=(10, 8)) # DIMENSIONS ARE 10 X 8
ax = fig.add_subplot(111, projection='3d') # I ADD A SUPLOT TO THE FIGUYRA I CREATED. THE NUMBER 111 INDICATES THAT I'M GOING TO HAVE A SINGLE SP, WITH 1 ROW AND 1 COLUMN
# IT'S IN THE PROJECTION THAT I SAY THE GRAPHIC WILL BE 3D

# PLOT THE 3D SCATTER PLOT
for species, color in cores.items(): # FOR EACH SPECIES AND COLOR, I'M GOING TO GO THROUGH THE DICTIONARY. SINCE I HAVE TWO VARIABLES, I PUT THE ITEMS(), BECAUSE I'M GOING TO ACCESS BOTH KEY AND VALUE
    subset = X[X['Target'] == species] # Comparison with Boolean Result. If true, it goes into my subset
    ax.scatter(subset['sepal length'], subset['sepal width'], subset['petal length'], c=color, label=species, marker='s')

# Add labels and leghend
ax.set_xlabel('Comprimento da Sépala') # x-axis label
ax.set_ylabel('Largura da Sépala') # y-axis label
ax.set_zlabel('Comprimento da Pétala') # z-axis label
ax.set_title('Gráfico de Dispersão 3D Iris') # Chart title
ax.legend() # chart legend

# Show the plot
plt.show()

# %%
import pandas as pd # Import the library to manipulate and visualize data
import matplotlib.pyplot as plt # Import the library to create charts
from mpl_toolkits.mplot3d import Axes3D # Import the package (mpl.toolkits) from this module (mplot3d) to create 3D graphics. we are importing the Axes3D class

# Color mapping for each category
categorias = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']  # List of flower categories from the Iris dataset
cores = {'Iris-setosa': 'brown', 'Iris-versicolor': 'pink', 'Iris-virginica': 'gray'}  # Dictionary associating color with the keys being the categories in the list in the previous line



# create the 3D figure
fig = plt.figure(figsize=(10, 8)) # DIMENSIONS ARE 10 X 8
ax = fig.add_subplot(111, projection='3d') # I ADD A SUPLOT TO THE FIGUYRA I CREATED. THE NUMBER 111 INDICATES THAT I'M GOING TO HAVE A SINGLE SP, WITH 1 ROW AND 1 COLUMN
# IT'S IN THE PROJECTION THAT I SAY THE GRAPHIC WILL BE 3D

# PLOT THE 3D SCATTER PLOT
for species, color in cores.items(): # FOR EACH SPECIES AND COLOR, I'M GOING TO GO THROUGH THE DICTIONARY. SINCE I HAVE TWO VARIABLES, I PUT THE ITEMS(), BECAUSE I'M GOING TO ACCESS BOTH KEY AND VALUE
    subset = X[X['Target'] == species] # Comparison with Boolean Result. If true, it goes into my subset
    ax.scatter(subset['sepal length'], subset['sepal width'], subset['petal width'], c=color, label=species, marker='p')

# Add labels and leghend
ax.set_xlabel('Comprimento da Sépala') # x-axis label
ax.set_ylabel('Largura da Sépala') # y-axis label
ax.set_zlabel('Largura da Pétala') # z-axis label
ax.set_title('Gráfico de Dispersão 3D Iris') # Chart title
ax.legend() # chart legend

# Show the plot
plt.show()

# %%
import pandas as pd # Import the library to manipulate and visualize data
import matplotlib.pyplot as plt # Import the library to create charts
from mpl_toolkits.mplot3d import Axes3D # Import the package (mpl.toolkits) from this module (mplot3d) to create 3D graphics. we are importing the Axes3D class

# Color mapping for each category
categorias = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']  # List of flower categories from the Iris dataset
cores = {'Iris-setosa': 'olive', 'Iris-versicolor': 'teal', 'Iris-virginica': 'navy'}  # Dictionary associating color with the keys being the categories in the list in the previous line



# create the 3D figure
fig = plt.figure(figsize=(10, 8)) # DIMENSIONS ARE 10 X 8
ax = fig.add_subplot(111, projection='3d') # I ADD A SUPLOT TO THE FIGUYRA I CREATED. THE NUMBER 111 INDICATES THAT I'M GOING TO HAVE A SINGLE SP, WITH 1 ROW AND 1 COLUMN
# IT'S IN THE PROJECTION THAT I SAY THE GRAPHIC WILL BE 3D

# PLOT THE 3D SCATTER PLOT
for species, color in cores.items(): # FOR EACH SPECIES AND COLOR, I'M GOING TO GO THROUGH THE DICTIONARY. SINCE I HAVE TWO VARIABLES, I PUT THE ITEMS(), BECAUSE I'M GOING TO ACCESS BOTH KEY AND VALUE
    subset = X[X['Target'] == species] # Comparison with Boolean Result. If true, it goes into my subset
    ax.scatter(subset['sepal length'], subset['petal length'], subset['petal width'], c=color, label=species, marker='*')

# Add labels and leghend
ax.set_xlabel('Comprimento da Sépala') # x-axis label
ax.set_ylabel('Comprimento da Pétala') # y-axis label
ax.set_zlabel('Largura da Pétala') # z-axis label
ax.set_title('Gráfico de Dispersão 3D Iris') # Chart title
ax.legend() # chart legend

# Show the plot
plt.show()

# %%
import pandas as pd # Import the library to manipulate and visualize data
import matplotlib.pyplot as plt # Import the library to create charts
from mpl_toolkits.mplot3d import Axes3D # Import the package (mpl.toolkits) from this module (mplot3d) to create 3D graphics. we are importing the Axes3D class

# Color mapping for each category
categorias = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']  # List of flower categories from the Iris dataset
cores = {'Iris-setosa': 'blue', 'Iris-versicolor': 'green', 'Iris-virginica': 'red'}  # Dictionary associating color with the keys being the categories in the list in the previous line



# create the 3D figure
fig = plt.figure(figsize=(10, 8)) # DIMENSIONS ARE 10 X 8
ax = fig.add_subplot(111, projection='3d') # I ADD A SUPLOT TO THE FIGUYRA I CREATED. THE NUMBER 111 INDICATES THAT I'M GOING TO HAVE A SINGLE SP, WITH 1 ROW AND 1 COLUMN
# IT'S IN THE PROJECTION THAT I SAY THE GRAPHIC WILL BE 3D

# PLOT THE 3D SCATTER PLOT
for species, color in cores.items(): # FOR EACH SPECIES AND COLOR, I'M GOING TO GO THROUGH THE DICTIONARY. SINCE I HAVE TWO VARIABLES, I PUT THE ITEMS(), BECAUSE I'M GOING TO ACCESS BOTH KEY AND VALUE
    subset = X[X['Target'] == species] # Comparison with Boolean Result. If true, it goes into my subset
    ax.scatter(subset['sepal width'], subset['petal length'], subset['petal width'], c=color, label=species, marker='h')

# Add labels and leghend
ax.set_xlabel('Largura da Sépala') # x-axis label
ax.set_ylabel('Comprimento da Pétala') # y-axis label
ax.set_zlabel('Largura da Pétala') # z-axis label
ax.set_title('Gráfico de Dispersão 3D Iris') # Chart title
ax.legend() # chart legend

# Show the plot
plt.show()

# %% [markdown]
# After viewing in 3D, I continue to remove the Sepal Width from the base

# %% [markdown]
# # Variable Analysis

# %% [markdown]
# ## Sepal Length:

# %% [markdown]
# It seems to be an important variable based on the boxplots, as it shows good separation between some classes.

# %% [markdown]
# ## Sepal Width:

# %% [markdown]
#  Often has less separability between classes and may have less discriminative impact.

# %% [markdown]
# ## Petal Length:

# %% [markdown]
# Clearly an important variable, it shows good separation between classes.

# %% [markdown]
# ## Petal Width:

# %% [markdown]
# Also important, with clear separability between classes.

# %% [markdown]
# # Rationale for Variable Deletion:

# %% [markdown]
# ## Based on the graphical analyses (boxplots and scatter plots) performed in the notebook, the variable "Sepal Width" can be considered for deletion for the following reasons:

# %% [markdown]
# *   Lower Separability: The separability of classes based on "Sepal Width" is less clear compared to other variables such as "Petal Length" and "Petal Width".
# *   Redundancy: There may be high correlation between "Sepal Width" and other variables, which does not add meaningful information to the model.

# %% [markdown]
# # Conclusion

# %% [markdown]
# I recommend deleting the "Sepal Width" variable. This decision is based on the lower separation capacity between the classes observed in the exploratory graphs. In addition, the elimination of this variable can simplify the model without significant loss of relevant information, maintaining the effectiveness of the analysis and the interpretability of the results.
#
#
# ## about which variable has a high correlation
# According to the correlation matrix made earlier and visualizing the plots, the variables that have the highest correlation are petal width and petal length, they are very close. But choosing only one, the most, is the petal width.
