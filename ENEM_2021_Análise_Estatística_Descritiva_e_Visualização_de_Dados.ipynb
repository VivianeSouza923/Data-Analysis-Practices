# %% [markdown]
# <a href="https://colab.research.google.com/github/VivianeSouza923/Data-Analysis-Practices/blob/main/ENEM_2021_An%C3%A1lise_Estat%C3%ADstica_Descritiva_e_Visualiza%C3%A7%C3%A3o_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/content/Enem_Fortaleza_2021_DisciplinaProbabilidadeEstatística.xlsx')
df.head()
# Out:
#    TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  TP_ANO_CONCLUIU  \
# 0                5       M                1            3                0
# 1                3       F                0            1                0
# 2                3       F                1            3                0
# 3                3       M                1            1                0
# 4               12       F                2            1                0
#
#    TP_ESCOLA  TP_DEPENDENCIA_ADM_ESC  TP_PRESENCA_CN  TP_PRESENCA_CH  \
# 0          2                       4               1               1
# 1          3                       4               1               1
# 2          2                       2               1               1
# 3          2                       2               1               1
# 4          2                       2               1               1
#
#    TP_PRESENCA_LC  ...  TP_STATUS_REDACAO  NU_NOTA_COMP1  NU_NOTA_COMP2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16588 entries, 0 to 16587
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TP_FAIXA_ETARIA         16588 non-null  int64
#  1   TP_SEXO                 16588 non-null  object
#  2   TP_ESTADO_CIVIL         16588 non-null  int64
#  3   TP_COR_RACA             16588 non-null  int64
#  4   TP_ANO_CONCLUIU         16588 non-null  int64
#  5   TP_ESCOLA               16588 non-null  int64
#  6   TP_DEPENDENCIA_ADM_ESC  16588 non-null  int64
#  7   TP_PRESENCA_CN          16588 non-null  int64
#  8   TP_PRESENCA_CH          16588 non-null  int64
#  9   TP_PRESENCA_LC          16588 non-null  int64
#  10  TP_PRESENCA_MT          16588 non-null  int64
#  11  CO_PROVA_CN             16588 non-null  int64
#  12  CO_PROVA_CH             16588 non-null  int64
#  13  CO_PROVA_LC             16588 non-null  int64
# ...

# %%
tp_faixa_etaria = {
    1:'Menor de 17 anos',
    2:'17 anos',
    3:'18 anos',
    4:'19 anos',
    5:'20 anos',
    6:'21 anos',
    7:'22 anos',
    8:'23 anos',
    9:'24 anos',
    10:'25 anos',
    11:'Entre 26 e 30 anos',
    12:'Entre 31 e 35 anos',
    13:'Entre 36 e 40 anos',
    14:'Entre 41 e 45 anos',
    15:'Entre 46 e 50 anos',
    16:'Entre 51 e 55 anos',
    17:'Entre 56 e 60 anos',
    18:'Entre 61 e 65 anos',
    19:'Entre 66 e 70 anos',
    20:'Maior de 70 anos'
}

df['TP_FAIXA_ETARIA'].replace(tp_faixa_etaria, inplace=True)
df
# Out:
#           TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  \
# 0                 20 anos       M                1            3
# 1                 18 anos       F                0            1
# 2                 18 anos       F                1            3
# 3                 18 anos       M                1            1
# 4      Entre 31 e 35 anos       F                2            1
# ...                   ...     ...              ...          ...
# 16583             19 anos       F                1            2
# 16584             18 anos       F                1            1
# 16585             18 anos       M                1            1
# 16586             18 anos       F                1            3
# 16587             17 anos       M                2            2
#
#        TP_ANO_CONCLUIU  TP_ESCOLA  TP_DEPENDENCIA_ADM_ESC  TP_PRESENCA_CN  \
# 0                    0          2                       4               1
# ...

# %%
df['TP_SEXO'].replace({'M':'Masculino', 'F':'Feminino'}, inplace=True)
df
# Out:
#           TP_FAIXA_ETARIA    TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  \
# 0                 20 anos  Masculino                1            3
# 1                 18 anos   Feminino                0            1
# 2                 18 anos   Feminino                1            3
# 3                 18 anos  Masculino                1            1
# 4      Entre 31 e 35 anos   Feminino                2            1
# ...                   ...        ...              ...          ...
# 16583             19 anos   Feminino                1            2
# 16584             18 anos   Feminino                1            1
# 16585             18 anos  Masculino                1            1
# 16586             18 anos   Feminino                1            3
# 16587             17 anos  Masculino                2            2
#
#        TP_ANO_CONCLUIU  TP_ESCOLA  TP_DEPENDENCIA_ADM_ESC  TP_PRESENCA_CN  \
# 0                    0          2                       4               1
# ...

# %%
df['TP_ESTADO_CIVIL'].replace({
    0:'Não informado',
    1:'Solteiro',
    2:'Casado(a)/Mora com companheiro(a)',
    3:'Divorciado(o)/Desquitado(a)/Separado(a)',
    4:'Viúvo(a)'
    },
    inplace=True)

df
# Out:
#           TP_FAIXA_ETARIA    TP_SEXO                    TP_ESTADO_CIVIL  \
# 0                 20 anos  Masculino                           Solteiro
# 1                 18 anos   Feminino                      Não informado
# 2                 18 anos   Feminino                           Solteiro
# 3                 18 anos  Masculino                           Solteiro
# 4      Entre 31 e 35 anos   Feminino  Casado(a)/Mora com companheiro(a)
# ...                   ...        ...                                ...
# 16583             19 anos   Feminino                           Solteiro
# 16584             18 anos   Feminino                           Solteiro
# 16585             18 anos  Masculino                           Solteiro
# 16586             18 anos   Feminino                           Solteiro
# 16587             17 anos  Masculino  Casado(a)/Mora com companheiro(a)
#
#        TP_COR_RACA  TP_ANO_CONCLUIU  TP_ESCOLA  TP_DEPENDENCIA_ADM_ESC  \
# ...

# %%
df['TP_COR_RACA'].replace({
    0:'Não declarado',
    1:'Branca',
    2:'Preta',
    3:'Parda',
    4:'Amarela',
    5:'Indígena',
    6:'Não dispõe da informação'
},
                                 inplace=True)
df
# Out:
#           TP_FAIXA_ETARIA    TP_SEXO                    TP_ESTADO_CIVIL  \
# 0                 20 anos  Masculino                           Solteiro
# 1                 18 anos   Feminino                      Não informado
# 2                 18 anos   Feminino                           Solteiro
# 3                 18 anos  Masculino                           Solteiro
# 4      Entre 31 e 35 anos   Feminino  Casado(a)/Mora com companheiro(a)
# ...                   ...        ...                                ...
# 16583             19 anos   Feminino                           Solteiro
# 16584             18 anos   Feminino                           Solteiro
# 16585             18 anos  Masculino                           Solteiro
# 16586             18 anos   Feminino                           Solteiro
# 16587             17 anos  Masculino  Casado(a)/Mora com companheiro(a)
#
#       TP_COR_RACA  TP_ANO_CONCLUIU  TP_ESCOLA  TP_DEPENDENCIA_ADM_ESC  \
# ...

# %%
tp_ano_concluiu = {
    0:'Não informado',
    1:'2020',
    2:'2019',
    3:'2018',
    4:'2017',
    5:'2016',
    6:'2015',
    7:'2014',
    8:'2013',
    9:'2012',
    10:'2011',
    11:'2010',
    12:'2009',
    13:'2008',
    14:'2007',
    15:'Antes de 2007'
}

df['TP_ANO_CONCLUIU'].replace(tp_ano_concluiu, inplace=True)
df
# Out:
#           TP_FAIXA_ETARIA    TP_SEXO                    TP_ESTADO_CIVIL  \
# 0                 20 anos  Masculino                           Solteiro
# 1                 18 anos   Feminino                      Não informado
# 2                 18 anos   Feminino                           Solteiro
# 3                 18 anos  Masculino                           Solteiro
# 4      Entre 31 e 35 anos   Feminino  Casado(a)/Mora com companheiro(a)
# ...                   ...        ...                                ...
# 16583             19 anos   Feminino                           Solteiro
# 16584             18 anos   Feminino                           Solteiro
# 16585             18 anos  Masculino                           Solteiro
# 16586             18 anos   Feminino                           Solteiro
# 16587             17 anos  Masculino  Casado(a)/Mora com companheiro(a)
#
#       TP_COR_RACA TP_ANO_CONCLUIU  TP_ESCOLA  TP_DEPENDENCIA_ADM_ESC  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16588 entries, 0 to 16587
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TP_FAIXA_ETARIA         16588 non-null  object
#  1   TP_SEXO                 16588 non-null  object
#  2   TP_ESTADO_CIVIL         16588 non-null  object
#  3   TP_COR_RACA             16588 non-null  object
#  4   TP_ANO_CONCLUIU         16588 non-null  object
#  5   TP_ESCOLA               16588 non-null  int64
#  6   TP_DEPENDENCIA_ADM_ESC  16588 non-null  int64
#  7   TP_PRESENCA_CN          16588 non-null  int64
#  8   TP_PRESENCA_CH          16588 non-null  int64
#  9   TP_PRESENCA_LC          16588 non-null  int64
#  10  TP_PRESENCA_MT          16588 non-null  int64
#  11  CO_PROVA_CN             16588 non-null  int64
#  12  CO_PROVA_CH             16588 non-null  int64
#  13  CO_PROVA_LC             16588 non-null  int64
# ...

# %%
df['TP_ESCOLA'].replace({1:'Não respondeu', 2:'Pública', 3:'Privada'}, inplace=True)
df
# Out:
#           TP_FAIXA_ETARIA    TP_SEXO                    TP_ESTADO_CIVIL  \
# 0                 20 anos  Masculino                           Solteiro
# 1                 18 anos   Feminino                      Não informado
# 2                 18 anos   Feminino                           Solteiro
# 3                 18 anos  Masculino                           Solteiro
# 4      Entre 31 e 35 anos   Feminino  Casado(a)/Mora com companheiro(a)
# ...                   ...        ...                                ...
# 16583             19 anos   Feminino                           Solteiro
# 16584             18 anos   Feminino                           Solteiro
# 16585             18 anos  Masculino                           Solteiro
# 16586             18 anos   Feminino                           Solteiro
# 16587             17 anos  Masculino  Casado(a)/Mora com companheiro(a)
#
#       TP_COR_RACA TP_ANO_CONCLUIU TP_ESCOLA  TP_DEPENDENCIA_ADM_ESC  \
# ...

# %%
df['TP_DEPENDENCIA_ADM_ESC'].replace({1:'Federal', 2:'Estadual', 3:'Municipal', 4:'Privada'}, inplace=True)
df
# Out:
#           TP_FAIXA_ETARIA    TP_SEXO                    TP_ESTADO_CIVIL  \
# 0                 20 anos  Masculino                           Solteiro
# 1                 18 anos   Feminino                      Não informado
# 2                 18 anos   Feminino                           Solteiro
# 3                 18 anos  Masculino                           Solteiro
# 4      Entre 31 e 35 anos   Feminino  Casado(a)/Mora com companheiro(a)
# ...                   ...        ...                                ...
# 16583             19 anos   Feminino                           Solteiro
# 16584             18 anos   Feminino                           Solteiro
# 16585             18 anos  Masculino                           Solteiro
# 16586             18 anos   Feminino                           Solteiro
# 16587             17 anos  Masculino  Casado(a)/Mora com companheiro(a)
#
#       TP_COR_RACA TP_ANO_CONCLUIU TP_ESCOLA TP_DEPENDENCIA_ADM_ESC  \
# ...

# %%
df['TP_PRESENCA_CN'].replace({0:'Faltou à prova', 1:'Presente na prova', 2:'Eliminado na prova'}, inplace=True)
df
# Out:
#           TP_FAIXA_ETARIA    TP_SEXO                    TP_ESTADO_CIVIL  \
# 0                 20 anos  Masculino                           Solteiro
# 1                 18 anos   Feminino                      Não informado
# 2                 18 anos   Feminino                           Solteiro
# 3                 18 anos  Masculino                           Solteiro
# 4      Entre 31 e 35 anos   Feminino  Casado(a)/Mora com companheiro(a)
# ...                   ...        ...                                ...
# 16583             19 anos   Feminino                           Solteiro
# 16584             18 anos   Feminino                           Solteiro
# 16585             18 anos  Masculino                           Solteiro
# 16586             18 anos   Feminino                           Solteiro
# 16587             17 anos  Masculino  Casado(a)/Mora com companheiro(a)
#
#       TP_COR_RACA TP_ANO_CONCLUIU TP_ESCOLA TP_DEPENDENCIA_ADM_ESC  \
# ...

# %%
df['TP_PRESENCA_CH'].replace({0:'Faltou à prova', 1:'Presente na prova', 2:'Eliminado na prova'}, inplace=True)
df
# Out:
#           TP_FAIXA_ETARIA    TP_SEXO                    TP_ESTADO_CIVIL  \
# 0                 20 anos  Masculino                           Solteiro
# 1                 18 anos   Feminino                      Não informado
# 2                 18 anos   Feminino                           Solteiro
# 3                 18 anos  Masculino                           Solteiro
# 4      Entre 31 e 35 anos   Feminino  Casado(a)/Mora com companheiro(a)
# ...                   ...        ...                                ...
# 16583             19 anos   Feminino                           Solteiro
# 16584             18 anos   Feminino                           Solteiro
# 16585             18 anos  Masculino                           Solteiro
# 16586             18 anos   Feminino                           Solteiro
# 16587             17 anos  Masculino  Casado(a)/Mora com companheiro(a)
#
#       TP_COR_RACA TP_ANO_CONCLUIU TP_ESCOLA TP_DEPENDENCIA_ADM_ESC  \
# ...

# %%
df['TP_PRESENCA_LC'].replace({0:'Faltou à prova', 1:'Presente na prova', 2:'Eliminado na prova'}, inplace=True)
df
# Out:
#           TP_FAIXA_ETARIA    TP_SEXO                    TP_ESTADO_CIVIL  \
# 0                 20 anos  Masculino                           Solteiro
# 1                 18 anos   Feminino                      Não informado
# 2                 18 anos   Feminino                           Solteiro
# 3                 18 anos  Masculino                           Solteiro
# 4      Entre 31 e 35 anos   Feminino  Casado(a)/Mora com companheiro(a)
# ...                   ...        ...                                ...
# 16583             19 anos   Feminino                           Solteiro
# 16584             18 anos   Feminino                           Solteiro
# 16585             18 anos  Masculino                           Solteiro
# 16586             18 anos   Feminino                           Solteiro
# 16587             17 anos  Masculino  Casado(a)/Mora com companheiro(a)
#
#       TP_COR_RACA TP_ANO_CONCLUIU TP_ESCOLA TP_DEPENDENCIA_ADM_ESC  \
# ...

# %%
df['TP_PRESENCA_MT'].replace({0:'Faltou à prova', 1:'Presente na prova', 2:'Eliminado na prova'}, inplace=True)
df
# Out:
#           TP_FAIXA_ETARIA    TP_SEXO                    TP_ESTADO_CIVIL  \
# 0                 20 anos  Masculino                           Solteiro
# 1                 18 anos   Feminino                      Não informado
# 2                 18 anos   Feminino                           Solteiro
# 3                 18 anos  Masculino                           Solteiro
# 4      Entre 31 e 35 anos   Feminino  Casado(a)/Mora com companheiro(a)
# ...                   ...        ...                                ...
# 16583             19 anos   Feminino                           Solteiro
# 16584             18 anos   Feminino                           Solteiro
# 16585             18 anos  Masculino                           Solteiro
# 16586             18 anos   Feminino                           Solteiro
# 16587             17 anos  Masculino  Casado(a)/Mora com companheiro(a)
#
#       TP_COR_RACA TP_ANO_CONCLUIU TP_ESCOLA TP_DEPENDENCIA_ADM_ESC  \
# ...

# %%
cor_prova = {
    909:'Azul',
    910:'Amarela',
    911:'Cinza',
    912:'Rosa',
    915:'Laranja - Braille',
    916:'Laranja - Adpatada Ledor',
    917:'Verde - Videoprova - Libras',
    989:'Azul(Reaplicação)',
    990:'Amarela(Reaplicação)',
    991:'Cinza(Reaplicação)',
    992:'Rosa(Reaplicação)',
    996:'Laranja - Adpatada Ledor(Reaplicação)',
    1011:'Azul (Digital)',
    1012:'Amarela (Digital)',
    1013:'Rosa (Digital)',
    1014:'Cinza (Digital)',
    1045:'Azul (Segunda oportunidade)',
    1046:'Amarela (Segunda oportunidade)',
    1047:'Cinza (Segunda oportuniddade)',
    1048:'Rosa (Segunda oportunidade)',
    1052:'Laranja - Adpatada Ledor (Segunda oportunidade)'


}




df['CO_PROVA_CN'].replace(cor_prova, inplace=True)
df['CO_PROVA_CN'].head(40)
# Out:
# 0               Cinza
# 1               Cinza
# 2               Cinza
# 3                Rosa
# 4                Azul
# 5             Amarela
# 6             Amarela
# 7             Amarela
# 8               Cinza
# 9                Rosa
# 10               Rosa
# 11              Cinza
# 12               Rosa
# 13            Amarela
# 14               Rosa
# 15            Amarela
# 16    Cinza (Digital)
# 17            Amarela
# 18              Cinza
# 19               Azul
# 20              Cinza
# 21               Rosa
# 22               Rosa
# 23              Cinza
# 24            Amarela
# 25               Rosa
# 26               Rosa
# 27            Amarela
# 28              Cinza
# 29            Amarela
# 30               Rosa
# 31              Cinza
# 32               Azul
# 33              Cinza
# 34            Amarela
# 35               Azul
# 36               Azul
# 37            Amarela
# 38               Azul
# 39               Rosa
# Name: CO_PROVA_CN, dtype: object

# %%
cor_cn = {
    879:'Azul',
    880:'Amarela',
    881:'Branca',
    882:'Rosa',
    885:'Laranja - Braille',
    886:'Laranja - Adpatada Ledor',
    887:'Verde - Videoprova - Libras',
    959:'Azul(Reaplicação)',
    960:'Amarela(Reaplicação)',
    961:'Branca(Reaplicação)',
    962:'Rosa(Reaplicação)',
    966:'Laranja - Adpatada Ledor(Reaplicação)',
    999:'Azul (Digital)',
    1000:'Amarela (Digital)',
    1002:'Rosa (Digital)',
    1001:'Branca (Digital)',
    1015:'Azul (Segunda oportunidade)',
    1016:'Amarela (Segunda oportunidade)',
    1017:'Branca (Segunda oportuniddade)',
    1018:'Rosa (Segunda oportunidade)',
    1022:'Laranja - Adpatada Ledor (Segunda oportunidade)'


}

df['CO_PROVA_CH'].replace(cor_cn, inplace=True)
df['CO_PROVA_CH']
# Out:
# 0        Amarela
# 1        Amarela
# 2        Amarela
# 3           Rosa
# 4         Branca
#           ...
# 16583     Branca
# 16584    Amarela
# 16585     Branca
# 16586       Azul
# 16587       Azul
# Name: CO_PROVA_CH, Length: 16588, dtype: object

# %%
cor_lc = {
    889:'Azul',
    890:'Amarela',
    891:'Rosa',
    892:'Branca',
    895:'Laranja - Braille',
    896:'Laranja - Adpatada Ledor',
    897:'Verde - Videoprova - Libras',
    969:'Azul(Reaplicação)',
    970:'Amarela(Reaplicação)',
    971:'Rosa(Reaplicação)',
    972:'Branca(Reaplicação)',
    976:'Laranja - Adpatada Ledor(Reaplicação)',
    1003:'Azul (Digital)',
    1004:'Amarela (Digital)',
    1005:'Branca (Digital)',
    1006:'Rosa (Digital)',
    1025:'Azul (Segunda oportunidade)',
    1026:'Amarela (Segunda oportunidade)',
    1027:'Rosa (Segunda oportuniddade)',
    1028:'Branca (Segunda oportunidade)',
    1032:'Laranja - Adpatada Ledor (Segunda oportunidade)'


}

df['CO_PROVA_LC'].replace(cor_lc, inplace=True)
df['CO_PROVA_LC'].head(10)
# Out:
# 0    Amarela
# 1    Amarela
# 2    Amarela
# 3       Rosa
# 4     Branca
# 5       Azul
# 6       Azul
# 7       Azul
# 8    Amarela
# 9       Rosa
# Name: CO_PROVA_LC, dtype: object

# %%
cor_mt = {
    899:'Azul',
    900:'Amarela',
    901:'Rosa',
    902:'Cinza',
    905:'Laranja - Braille',
    906:'Laranja - Adpatada Ledor',
    907:'Verde - Videoprova - Libras',
    979:'Azul(Reaplicação)',
    980:'Amarela(Reaplicação)',
    981:'Rosa(Reaplicação)',
    982:'Cinza(Reaplicação)',
    986:'Laranja - Adpatada Ledor(Reaplicação)',
    1007:'Azul (Digital)',
    1008:'Amarela (Digital)',
    1009:'Rosa (Digital)',
    1010:'Cinza (Digital)',
    1035:'Azul (Segunda oportunidade)',
    1036:'Amarela (Segunda oportunidade)',
    1037:'Cinza (Segunda oportuniddade)',
    1038:'Rosa (Segunda oportunidade)',
    1042:'Laranja - Adpatada Ledor (Segunda oportunidade)'


}

df['CO_PROVA_MT'].replace(cor_mt, inplace=True)
df['CO_PROVA_MT'].head(10)
# Out:
# 0      Cinza
# 1      Cinza
# 2      Cinza
# 3       Rosa
# 4       Azul
# 5    Amarela
# 6    Amarela
# 7    Amarela
# 8      Cinza
# 9       Rosa
# Name: CO_PROVA_MT, dtype: object

# %%
df['TP_LINGUA'].replace({0:'Inglês', 1:'Espanhol'}, inplace=True)
df['TP_LINGUA'].head()
# Out:
# 0    Espanhol
# 1      Inglês
# 2    Espanhol
# 3    Espanhol
# 4      Inglês
# Name: TP_LINGUA, dtype: object

# %%
status_redacao = {
    1:'Sem problemas',
    2:'Anulada',
    3:'Cópia texto motivador',
    4:'Em branco',
    6:'Fuga ao tema',
    7:'Não atendimento ao tipo textual',
    8:'Texto insuficiente',
    9:'Parte desconectada'
}

df['TP_STATUS_REDACAO'].replace(status_redacao, inplace=True)
df['TP_STATUS_REDACAO'].head(40)
# Out:
# 0     Sem problemas
# 1     Sem problemas
# 2     Sem problemas
# 3     Sem problemas
# 4     Sem problemas
# 5     Sem problemas
# 6     Sem problemas
# 7     Sem problemas
# 8     Sem problemas
# 9     Sem problemas
# 10    Sem problemas
# 11    Sem problemas
# 12    Sem problemas
# 13    Sem problemas
# 14    Sem problemas
# 15    Sem problemas
# 16    Sem problemas
# 17    Sem problemas
# 18    Sem problemas
# 19    Sem problemas
# 20    Sem problemas
# 21    Sem problemas
# 22        Em branco
# 23    Sem problemas
# 24        Em branco
# 25    Sem problemas
# 26    Sem problemas
# 27    Sem problemas
# 28    Sem problemas
# 29    Sem problemas
# 30    Sem problemas
# 31    Sem problemas
# 32    Sem problemas
# 33    Sem problemas
# 34    Sem problemas
# 35    Sem problemas
# 36    Sem problemas
# 37    Sem problemas
# 38    Sem problemas
# 39    Sem problemas
# Name: TP_STATUS_REDACAO, dtype: object

# %%
q001 = {
    'A':'Nunca estudou.',
    'B':'Não completou a 4ª série/5º ano do Ensino Fundamental.',
    'C':'Completou a 4ª série/5º ano, mas não completou a 8ª série/9º ano do Ensino Fundamental.',
    'D':'Completou a 8ª série/9º ano, mas não completou o Ensino Médio.',
    'E':'Completou o Ensino Médio, mas não completou a Faculdade.',
    'F':'Completou a Faculdade, mas não completou a Pós-graduação.',
    'G':'Completou a Pós-graduação.',
    'H':'Não sei.'
    }

df['Q001'].replace(q001, inplace=True)
df.head()
# Out:
#       TP_FAIXA_ETARIA    TP_SEXO                    TP_ESTADO_CIVIL  \
# 0             20 anos  Masculino                           Solteiro
# 1             18 anos   Feminino                      Não informado
# 2             18 anos   Feminino                           Solteiro
# 3             18 anos  Masculino                           Solteiro
# 4  Entre 31 e 35 anos   Feminino  Casado(a)/Mora com companheiro(a)
#
#   TP_COR_RACA TP_ANO_CONCLUIU TP_ESCOLA TP_DEPENDENCIA_ADM_ESC  \
# 0       Parda   Não informado   Pública                Privada
# 1      Branca   Não informado   Privada                Privada
# 2       Parda   Não informado   Pública               Estadual
# 3      Branca   Não informado   Pública               Estadual
# 4      Branca   Não informado   Pública               Estadual
#
#       TP_PRESENCA_CN     TP_PRESENCA_CH     TP_PRESENCA_LC  ...  \
# 0  Presente na prova  Presente na prova  Presente na prova  ...
# ...

# %%
df['Q002'].replace(q001, inplace=True)
df.head()
# Out:
#       TP_FAIXA_ETARIA    TP_SEXO                    TP_ESTADO_CIVIL  \
# 0             20 anos  Masculino                           Solteiro
# 1             18 anos   Feminino                      Não informado
# 2             18 anos   Feminino                           Solteiro
# 3             18 anos  Masculino                           Solteiro
# 4  Entre 31 e 35 anos   Feminino  Casado(a)/Mora com companheiro(a)
#
#   TP_COR_RACA TP_ANO_CONCLUIU TP_ESCOLA TP_DEPENDENCIA_ADM_ESC  \
# 0       Parda   Não informado   Pública                Privada
# 1      Branca   Não informado   Privada                Privada
# 2       Parda   Não informado   Pública               Estadual
# 3      Branca   Não informado   Pública               Estadual
# 4      Branca   Não informado   Pública               Estadual
#
#       TP_PRESENCA_CN     TP_PRESENCA_CH     TP_PRESENCA_LC  ...  \
# 0  Presente na prova  Presente na prova  Presente na prova  ...
# ...

# %%
q006 = {
    'A':'Nenhuma Renda.',
    'B':'Até R$ 1.100,00',
    'C':'De R$ 1.100,01 até R$ 1.650,00',
    'D':'De R$ 1.650,01 até R$ 2.200,00',
    'E':'De R$ 2.200,01 até R$ 2.750,00',
    'F':'De R$ 2.750,01 até R$ 3.300,00',
    'G':'De R$ 3.300,01 até R$ 4.400,00',
    'H':'De R$ 4.400,01 até R$ 5.500,00',
    'I':'De R$ 5.500,01 até R$ 6.600,00',
    'J':'De R$ 6.600,01 até R$ 7.700,00',
    'K':'De R$ 7.700,01 até R$ 8.800,00',
    'L':'De R$ 8.800,01 até R$ 9.900,00',
    'M':'De R$ 9.900,01 até R$ 11.000,00',
    'N':'De R$ 11.000,01 até R$ 13.200,00',
    'O':'De R$ 13.200,01 até R$ 16.500,00',
    'P':'De R$ 16.500,01 até R$ 22.000,00',
    'Q':'Acima de R$ 22.000,00.'



}
df['Q006'].replace(q006, inplace=True)
df.head()
# Out:
#       TP_FAIXA_ETARIA    TP_SEXO                    TP_ESTADO_CIVIL  \
# 0             20 anos  Masculino                           Solteiro
# 1             18 anos   Feminino                      Não informado
# 2             18 anos   Feminino                           Solteiro
# 3             18 anos  Masculino                           Solteiro
# 4  Entre 31 e 35 anos   Feminino  Casado(a)/Mora com companheiro(a)
#
#   TP_COR_RACA TP_ANO_CONCLUIU TP_ESCOLA TP_DEPENDENCIA_ADM_ESC  \
# 0       Parda   Não informado   Pública                Privada
# 1      Branca   Não informado   Privada                Privada
# 2       Parda   Não informado   Pública               Estadual
# 3      Branca   Não informado   Pública               Estadual
# 4      Branca   Não informado   Pública               Estadual
#
#       TP_PRESENCA_CN     TP_PRESENCA_CH     TP_PRESENCA_LC  ...  \
# 0  Presente na prova  Presente na prova  Presente na prova  ...
# ...

# %% [markdown]
# ## a) Calcular média, moda, mediana, amplitude, variância, desvio padrão e CV para variáveis quantitativas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16588 entries, 0 to 16587
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TP_FAIXA_ETARIA         16588 non-null  object
#  1   TP_SEXO                 16588 non-null  object
#  2   TP_ESTADO_CIVIL         16588 non-null  object
#  3   TP_COR_RACA             16588 non-null  object
#  4   TP_ANO_CONCLUIU         16588 non-null  object
#  5   TP_ESCOLA               16588 non-null  object
#  6   TP_DEPENDENCIA_ADM_ESC  16588 non-null  object
#  7   TP_PRESENCA_CN          16588 non-null  object
#  8   TP_PRESENCA_CH          16588 non-null  object
#  9   TP_PRESENCA_LC          16588 non-null  object
#  10  TP_PRESENCA_MT          16588 non-null  object
#  11  CO_PROVA_CN             16588 non-null  object
#  12  CO_PROVA_CH             16588 non-null  object
#  13  CO_PROVA_LC             16588 non-null  object
# ...

# %% [markdown]
# ### VARIÁVEL NU_NOTA_CN

# %%
# cálculo média:

media_NU_NOTA_CN = df['NU_NOTA_CN'].mean()
media_NU_NOTA_CN
# Out:
# 482.8640704123463

# %%
# cálculo mediana
mediana_NU_NOTA_CN = df['NU_NOTA_CN'].median()
mediana_NU_NOTA_CN
# Out:
# 468.0

# %%
# cálculo amplitude:

amplitude_NU_NOTA_CN = df['NU_NOTA_CN'].max() - df['NU_NOTA_CN'].min()
amplitude_NU_NOTA_CN
# Out:
# 815.1

# %%
# cálculo variância:

variancia_NU_NOTA_CN = df['NU_NOTA_CN'].var()
variancia_NU_NOTA_CN
# Out:
# 7043.569747752201

# %%
# cálculo desvio padrão:

std_NU_NOTA_CN = df['NU_NOTA_CN'].std()
std_NU_NOTA_CN
# Out:
# 83.92597778847859

# %%
# cálculo coeficiente de variancia:

cv_NU_NOTA_CN = (df['NU_NOTA_CN'].std() / df['NU_NOTA_CN'].mean()) * 100
cv_NU_NOTA_CN
# Out:
# 17.380870296853775

# %% [markdown]
# ### ** Variável  NU_NOTA_CH  **

# %%
# cálculoo média:

meddia_NU_NOTA_CH  = df['NU_NOTA_CH'].mean()
meddia_NU_NOTA_CH
# Out:
# 513.9334217506631

# %%
# cálculo moda:

modda_NU_NOTA_CH  = df['NU_NOTA_CH'].mode()
modda_NU_NOTA_CH
# Out:
# 0    0.0
# Name: NU_NOTA_CH, dtype: float64

# %%
# cálculo mediana:

mediana_NU_NOTA_CH  = df['NU_NOTA_CH'].median()
mediana_NU_NOTA_CH
# Out:
# 511.5

# %%
# cálculo amplitude:

amplitudde_NU_NOTA_CH  = df['NU_NOTA_CH'].max() - df[ 'NU_NOTA_CH'].min()
amplitudde_NU_NOTA_CH
# Out:
# 846.9

# %%
# c´alculo variância:

variancia_NU_NOTA_CH  = df['NU_NOTA_CH'].var()
variancia_NU_NOTA_CH
# Out:
# 9208.472006449716

# %%
# cálculo desvio padrão:

std_NU_NOTA_CH  = df['NU_NOTA_CH'].std()
std_NU_NOTA_CH
# Out:
# 95.9607836902644

# %%
# cálculo coeficiente de variação:

cv_NU_NOTA_CH  = (df['NU_NOTA_CH'].std() / df['NU_NOTA_CH'].mean()) * 100
cv_NU_NOTA_CH
# Out:
# 18.671831725475947

# %% [markdown]
# ### VARIÁVEL NU_NOTA_LC

# %%
# CÁLCULO MÉDIA:

media_NU_NOTA_LC = df['NU_NOTA_LC'].mean()
media_NU_NOTA_LC
# Out:
# 498.08561610802985

# %%
# cálculo moda:

moda_NU_NOTA_LC = df['NU_NOTA_LC'].mode()
moda_NU_NOTA_LC
# Out:
# 0    466.8
# 1    515.3
# Name: NU_NOTA_LC, dtype: float64

# %%
# cálculo mediana:

mediana_NU_NOTA_LC = df['NU_NOTA_LC'].median()
mediana_NU_NOTA_LC
# Out:
# 499.8

# %%
# cálculo amplitude:

amplitude_NU_NOTA_LC = df['NU_NOTA_LC'].max() - df['NU_NOTA_LC'].min()
amplitude_NU_NOTA_LC
# Out:
# 760.5

# %%
# cálculo variância:

variancia_NU_NOTA_LC = df['NU_NOTA_LC'].var()
variancia_NU_NOTA_LC
# Out:
# 6253.941498040837

# %%
# cálculo desvio padrão:

std_NU_NOTA_LC = df['NU_NOTA_LC'].std()
std_NU_NOTA_LC
# Out:
# 79.08186579767094

# %%
# cálculo coeficiente de variancia:

cv_NU_NOTA_LC = df['NU_NOTA_LC'].var()
cv_NU_NOTA_LC
# Out:
# 6253.941498040837

# %% [markdown]
# ### variável NU_NOTA_MT

# %%
# cálculo média:

media_NU_NOTA_MT = df['NU_NOTA_MT'].mean()
media_NU_NOTA_MT
# Out:
# 532.0519592476488

# %%
# c´alculo moda:

moda_NU_NOTA_MT = df['NU_NOTA_MT'].mode()
moda_NU_NOTA_MT
# Out:
# 0    391.4
# 1    476.5
# Name: NU_NOTA_MT, dtype: float64

# %%
# cálculo mediana:

mediana_NU_NOTA_MT = df['NU_NOTA_MT'].median()
mediana_NU_NOTA_MT
# Out:
# 503.4

# %%
# cálculo amplitude:

amplitude_NU_NOTA_MT = df['NU_NOTA_MT'].max() - df['NU_NOTA_MT'].min()
amplitude_NU_NOTA_MT
# Out:
# 953.1

# %%
# cálculo variancia:

variancia_NU_NOTA_MT = df['NU_NOTA_MT'].var()
variancia_NU_NOTA_MT
# Out:
# 13888.712578906641

# %%
# cálculo desvio padrão

std_NU_NOTA_MT = df['NU_NOTA_MT'].std()
std_NU_NOTA_MT
# Out:
# 117.85038217547978

# %%
# cálculo coeficiente de variancia:

cv_NU_NOTA_MT = (df['NU_NOTA_MT'].std() / df['NU_NOTA_MT'].mean()) * 100
cv_NU_NOTA_MT
# Out:
# 22.150164119708684

# %% [markdown]
# ### variável NU_NOTA_COMP1

# %%
# cálculo media

media_NU_NOTA_COMP1 = df['NU_NOTA_COMP1'].mean()
media_NU_NOTA_COMP1
# Out:
# 117.1569809500844

# %%
# cálculo moda:

moda_NU_NOTA_COMP1 = df['NU_NOTA_COMP1'].mode()
moda_NU_NOTA_COMP1
# Out:
# 0    120
# Name: NU_NOTA_COMP1, dtype: int64

# %%
# cálculo mediana:

mediana_NU_NOTA_COMP1 = df['NU_NOTA_COMP1'].median()
mediana_NU_NOTA_COMP1
# Out:
# 120.0

# %%
# cálculo amplitude:

amplitudde_NU_NOTA_COMP1 = df['NU_NOTA_COMP1'].max() - df['NU_NOTA_COMP1'].min()
amplitudde_NU_NOTA_COMP1
# Out:
# 200

# %%
# cálculo variancia:

variancia_NU_NOTA_COMP1 = df['NU_NOTA_COMP1'].var()
variancia_NU_NOTA_COMP1
# Out:
# 1442.5949973838535

# %%
# cálculo desvio padrão:

std_NU_NOTA_COMP1 = df['NU_NOTA_COMP1'].std()
std_NU_NOTA_COMP1
# Out:
# 37.98150862438001

# %%
# cálculo coeificente de variancia:

cv_NU_NOTA_COMP1 = (df['NU_NOTA_COMP1'].std() / df['NU_NOTA_COMP1'].mean()) * 100
cv_NU_NOTA_COMP1
# Out:
# 32.41933030056682

# %% [markdown]
# ### variável NU_NOTA_COMP2

# %%
# cálculo média:

media_NU_NOTA_COMP2 = df['NU_NOTA_COMP2'].mean()
media_NU_NOTA_COMP2
# Out:
# 136.4347721244273

# %%
# cálculo moda:

moda_NU_NOTA_COMP2 = df['NU_NOTA_COMP2'].mode()
moda_NU_NOTA_COMP2
# Out:
# 0    120
# Name: NU_NOTA_COMP2, dtype: int64

# %%
# cálculo mediana:

mediana_NU_NOTA_COMP2 = df['NU_NOTA_COMP2'].median()
mediana_NU_NOTA_COMP2
# Out:
# 120.0

# %%
# c´alculo amplitude:

amplitude_NU_NOTA_COMP2 = df['NU_NOTA_COMP2'].max() - df['NU_NOTA_COMP2'].min()
amplitude_NU_NOTA_COMP2
# Out:
# 200

# %%
# cálculo variancia:

variancia_NU_NOTA_COMP2 = df['NU_NOTA_COMP2'].var()
variancia_NU_NOTA_COMP2
# Out:
# 2297.2660772555996

# %%
# cálculo desvio padrão:

std_NU_NOTA_COMP2 = df['NU_NOTA_COMP2'].std()
std_NU_NOTA_COMP2
# Out:
# 47.92980364299023

# %%
# cálculo coeficiente de variancia:

cv_NU_NOTA_COMP2 = (df['NU_NOTA_COMP2'].std() / df['NU_NOTA_COMP2'].mean()) * 100
cv_NU_NOTA_COMP2
# Out:
# 35.130196574285826

# %% [markdown]
# ### VARIÁVEL NU_NOTA_COMP3

# %%
# CÁLCULO MÉDDIA:

media_NU_NOTA_COMP3 = df['NU_NOTA_COMP3'].mean()
media_NU_NOTA_COMP3
# Out:
# 113.76657824933687

# %%
# cálculo moda:

moda_NU_NOTA_COMP3 = df['NU_NOTA_COMP3'].mode()
moda_NU_NOTA_COMP3
# Out:
# 0    120
# Name: NU_NOTA_COMP3, dtype: int64

# %%
# cálculo mediana:

mediana_NU_NOTA_COMP3 = df['NU_NOTA_COMP3'].median()
mediana_NU_NOTA_COMP3
# Out:
# 120.0

# %%
# cálculo amplitude:

amplitudde_NU_NOTA_COMP3 = df['NU_NOTA_COMP3'].max() - df['NU_NOTA_COMP3'].min()
amplitudde_NU_NOTA_COMP3
# Out:
# 200

# %%
# cálculo variancia:

variancia_NU_NOTA_COMP3 = df['NU_NOTA_COMP3'].var()
variancia_NU_NOTA_COMP3
# Out:
# 1532.4449382637868

# %%
# cálculo desvio padrão:

std_NU_NOTA_COMP3 = df['NU_NOTA_COMP3'].std()
std_NU_NOTA_COMP3
# Out:
# 39.1464549897406

# %%
# cálculo coenficiente de variancia:

cv_NU_NOTA_COMP3 = (df['NU_NOTA_COMP3'].std() / df['NU_NOTA_COMP3'].mean()) * 100
cv_NU_NOTA_COMP3
# Out:
# 34.409450993546756

# %% [markdown]
# ### variável NU_NOTA_COMP4

# %%
# cálculo média:

media_NU_NOTA_COMP4 = df['NU_NOTA_COMP4'].mean()
media_NU_NOTA_COMP4
# Out:
# 127.53556788039546

# %%
# cálculo moda:

moda_NU_NOTA_COMP4 = df['NU_NOTA_COMP4'].mode()
moda_NU_NOTA_COMP4
# Out:
# 0    120
# Name: NU_NOTA_COMP4, dtype: int64

# %%
# cálculo mediana:

mediana_NU_NOTA_COMP4 = df['NU_NOTA_COMP4'].median()
mediana_NU_NOTA_COMP4
# Out:
# 120.0

# %%
# cálculo amplitude:

amplitude_NU_NOTA_COMP4 = df['NU_NOTA_COMP4'].max() - df['NU_NOTA_COMP4'].min()
amplitude_NU_NOTA_COMP4
# Out:
# 200

# %%
# c´alculo variancia:

variancia_NU_NOTA_COMP4 = df['NU_NOTA_COMP4'].var()
variancia_NU_NOTA_COMP4
# Out:
# 1856.8067772924921

# %%
# cálculo desvio padrão:

std_NU_NOTA_COMP4 = df['NU_NOTA_COMP4'].std()
std_NU_NOTA_COMP4
# Out:
# 43.09068086364489

# %%
# cálculo coeficiente de variação:

cv_NU_NOTA_COMP4 = (df['NU_NOTA_COMP4'].std() / df['NU_NOTA_COMP4'].mean()) * 100
cv_NU_NOTA_COMP4
# Out:
# 33.78718704107383

# %% [markdown]
# ### variável NU_NOTA_COMP5

# %%
# cálculo méddia:

media_NU_NOTA_COMP5 = df['NU_NOTA_COMP5'].mean()
media_NU_NOTA_COMP5
# Out:
# 115.95249578008199

# %%
# cálculo moda:

moda_NU_NOTA_COMP5 = df['NU_NOTA_COMP5'].mode()
moda_NU_NOTA_COMP5
# Out:
# 0    120
# Name: NU_NOTA_COMP5, dtype: int64

# %%
# cálculo mediana:

mediana_NU_NOTA_COMP5 = df['NU_NOTA_COMP5'].median()
mediana_NU_NOTA_COMP5
# Out:
# 120.0

# %%
# cálculo amplitusde:

amplitude_NU_NOTA_COMP5 = df['NU_NOTA_COMP5'].max() - df['NU_NOTA_COMP5'].min()
amplitude_NU_NOTA_COMP5
# Out:
# 200

# %%
# cálculo variancia:

variancia_NU_NOTA_COMP5 = df['NU_NOTA_COMP5'].var()
variancia_NU_NOTA_COMP5
# Out:
# 4056.034880730374

# %%
# cálcuo desvio padrão:

std_NU_NOTA_COMP5 = df['NU_NOTA_COMP5'].std()
std_NU_NOTA_COMP5
# Out:
# 63.68700715789975

# %%
# cálculo coeficiente de variação:

cv_NU_NOTA_COMP5 = (df['NU_NOTA_COMP5'].std() / df['NU_NOTA_COMP5'].mean()) * 100
cv_NU_NOTA_COMP5
# Out:
# 54.92508525102375

# %% [markdown]
# ## b) Construir gráficos adequados para os pares de variáveis

# %% [markdown]
# ### Gráfico de dispersão (scatter plot) para NU_NOTA_CN e NU_NOTA_CH:

# %%
plt.scatter(df['NU_NOTA_CN'], df['NU_NOTA_CH'], c='purple')
plt.xlabel('NU_NOTA_CN')
plt.ylabel('NU_NOTA_CH')
plt.title('Gráfico de Dispersão entre NU_NOTA_CN e NU_NOTA_CH')
plt.show()

# %% [markdown]
# ### Gráfico de linha(line plot) para NU_NOTA_CN e NU_NOTA_LC:

# %%
# dimensões da figura
plt.figure(figsize=(10, 6))

df_clean = df.dropna(subset=['NU_NOTA_CN', 'NU_NOTA_LC'])

plt.plot(df_clean['NU_NOTA_CN'], df_clean['NU_NOTA_LC'], marker=',', color='pink') # o marker passa a forma que terá
plt.xlabel('NU_NOTA_CN')
plt.ylabel('NU_NOTA_LC')

plt.title(label='Gráfico de Linha entre NU_NOTA_CN e NU_NOTA_LC')

plt.grid(True)  # Adiciona grade ao gráfico

plt.show()

# %% [markdown]
# ### Gráfico de dispersão (scatter plot) para NU_NOTA_CN e NU_NOTA_MT:

# %%
df_cleasn = df.dropna(subset=['NU_NOTA_CN', 'NU_NOTA_MT'])
plt.scatter(df_cleasn['NU_NOTA_CN'], df_cleasn['NU_NOTA_MT'], color='red')


plt.xlabel('NU_NOTA_CN')
plt.ylabel('NU_NOTA_MT')
plt.title('Gráfico de Dispersão entre NU_NOTA_CN e NU_NOTA_MT')
plt.show()

# %% [markdown]
# ### Gráfico de linha(line plot) para NU_NOTA_CH e NU_NOTA_LC:

# %%
plt.figure(figsize=(10, 6))

df_clean = df.dropna(subset=['NU_NOTA_CH', 'NU_NOTA_LC'])

plt.plot(df_clean['NU_NOTA_CH'], df_clean['NU_NOTA_LC'], marker='o', color='teal')
plt.xlabel('NU_NOTA_CH')
plt.ylabel('NU_NOTA_LC')

plt.title(label='Gráfico de Linha entre NU_NOTA_CH e NU_NOTA_LC')

plt.grid(True)  # Adiciona grade ao gráfico

plt.show()

# %% [markdown]
# ### Gráfico de dispersão (scatter plot) para NU_NOTA_CH e NU_NOTA_MT:

# %%
df_cleasn = df.dropna(subset=['NU_NOTA_CH', 'NU_NOTA_MT'])
plt.scatter(df_cleasn['NU_NOTA_CH'], df_cleasn['NU_NOTA_MT'], color='navy')


plt.xlabel('NU_NOTA_CH')
plt.ylabel('NU_NOTA_MT')
plt.title('Gráfico de Dispersão entre NU_NOTA_CH e NU_NOTA_MT')
plt.show()

# %% [markdown]
# ### Gráfico de linha(line plot) para NU_NOTA_LC e NU_NOTA_MT:

# %%
plt.figure(figsize=(10, 6))

df_clean = df.dropna(subset=['NU_NOTA_LC', 'NU_NOTA_MT'])

plt.plot(df_clean['NU_NOTA_LC'], df_clean['NU_NOTA_MT'], marker='x', color='yellow')
plt.xlabel('NU_NOTA_LC')
plt.ylabel('NU_NOTA_MT')

plt.title(label='Gráfico de Linha entre NU_NOTA_LC e NU_NOTA_MT')

plt.grid(True)  # Adiciona grade ao gráfico

plt.show()

# %% [markdown]
# ### Gráfico de dispersão (scatter plot) para NU_NOTA_COMP1 e NU_NOTA_COMP2:
#
# ---

# %%
df_cleasn = df.dropna(subset=['NU_NOTA_COMP1', 'NU_NOTA_COMP2'])
plt.scatter(df_cleasn['NU_NOTA_COMP1'], df_cleasn['NU_NOTA_COMP2'], color='blue')


plt.xlabel('NU_NOTA_COMP1')
plt.ylabel('NU_NOTA_COMP2')
plt.title('Gráfico de Dispersão entre NU_NOTA_COMP1 e NU_NOTA_COMP2')
plt.show()

# %% [markdown]
# ### Gráfico de linha(line plot) para NU_NOTA_COMP1 e NU_NOTA_COMP3:

# %%
plt.figure(figsize=(10, 6))

df_clean = df.dropna(subset=['NU_NOTA_COMP1', 'NU_NOTA_COMP3'])

plt.plot(df_clean['NU_NOTA_COMP1'], df_clean['NU_NOTA_COMP3'], marker='+', color='green')
plt.xlabel('NU_NOTA_COMP1')
plt.ylabel('NU_NOTA_COMP3')

plt.title(label='Gráfico de Linha entre NU_NOTA_COMP1 e NU_NOTA_COMP3')

plt.grid(True)  # Adiciona grade ao gráfico

plt.show()

# %% [markdown]
# ### Gráfico de dispersão (scatter plot) para NU_NOTA_COMP1 e NU_NOTA_COMP4:

# %%
df_cleasn = df.dropna(subset=['NU_NOTA_COMP1', 'NU_NOTA_COMP4'])
plt.scatter(df_cleasn['NU_NOTA_COMP1'], df_cleasn['NU_NOTA_COMP4'], color='red')


plt.xlabel('NU_NOTA_COMP1')
plt.ylabel('NU_NOTA_COMP4')
plt.title('Gráfico de Dispersão entre NU_NOTA_COMP1 e NU_NOTA_COMP4')
plt.show()

# %% [markdown]
# ### Gráfico de linha(line plot) para NU_NOTA_COMP1 e NU_NOTA_COMP5:

# %%
plt.figure(figsize=(10, 6))

df_clean = df.dropna(subset=['NU_NOTA_COMP1', 'NU_NOTA_COMP5'])

plt.plot(df_clean['NU_NOTA_COMP1'], df_clean['NU_NOTA_COMP5'], marker='_', color='cyan')
plt.xlabel('NU_NOTA_COMP1')
plt.ylabel('NU_NOTA_COMP5')

plt.title(label='Gráfico de Linha entre NU_NOTA_COMP1 e NU_NOTA_COMP5')

plt.grid(True)  # Adiciona grade ao gráfico

plt.show()

# %% [markdown]
# ### Gráfico de dispersão (scatter plot) para NU_NOTA_COMP2 e NU_NOTA_COMP3:

# %%
df_cleasn = df.dropna(subset=['NU_NOTA_COMP2', 'NU_NOTA_COMP3'])
plt.scatter(df_cleasn['NU_NOTA_COMP2'], df_cleasn['NU_NOTA_COMP3'], color='magenta')


plt.xlabel('NU_NOTA_COMP2')
plt.ylabel('NU_NOTA_COMP3')
plt.title('Gráfico de Dispersão entre NU_NOTA_COMP2 e NU_NOTA_COMP3')
plt.show()

# %% [markdown]
# ### Gráfico de linha(line plot) para NU_NOTA_COMP2 e NU_NOTA_COMP4:

# %%
plt.figure(figsize=(10, 6))

df_clean = df.dropna(subset=['NU_NOTA_COMP2', 'NU_NOTA_COMP4'])

plt.plot(df_clean['NU_NOTA_COMP2'], df_clean['NU_NOTA_COMP4'], marker='s', color='yellow')
plt.xlabel('NU_NOTA_COMP2')
plt.ylabel('NU_NOTA_COMP4')

plt.title(label='Gráfico de Linha entre NU_NOTA_COMP2 e NU_NOTA_COMP4')

plt.grid(True)  # Adiciona grade ao gráfico

plt.show()

# %% [markdown]
# ### Gráfico de dispersão (scatter plot) para NU_NOTA_COMP2 e NU_NOTA_COMP5:

# %%
df_cleasn = df.dropna(subset=['NU_NOTA_COMP2', 'NU_NOTA_COMP5'])
plt.scatter(df_cleasn['NU_NOTA_COMP2'], df_cleasn['NU_NOTA_COMP5'], color='black')


plt.xlabel('NU_NOTA_COMP2')
plt.ylabel('NU_NOTA_COMP5')
plt.title('Gráfico de Dispersão entre NU_NOTA_COMP2 e NU_NOTA_COMP5')
plt.show()

# %% [markdown]
# ### Gráfico de linha(line plot) para NU_NOTA_COMP3 e NU_NOTA_COMP4:

# %%
plt.figure(figsize=(10, 6))

df_clean = df.dropna(subset=['NU_NOTA_COMP3', 'NU_NOTA_COMP4'])

plt.plot(df_clean['NU_NOTA_COMP3'], df_clean['NU_NOTA_COMP4'], marker='p', color='orange')
plt.xlabel('NU_NOTA_COMP3')
plt.ylabel('NU_NOTA_COMP4')

plt.title(label='Gráfico de Linha entre NU_NOTA_COMP3 e NU_NOTA_COMP4')

plt.grid(True)  # Adiciona grade ao gráfico

plt.show()

# %% [markdown]
# ### Gráfico de dispersão (scatter plot) para NU_NOTA_COMP3 e NU_NOTA_COMP5:

# %%
df_cleasn = df.dropna(subset=['NU_NOTA_COMP3', 'NU_NOTA_COMP5'])
plt.scatter(df_cleasn['NU_NOTA_COMP3'], df_cleasn['NU_NOTA_COMP5'], color='purple')


plt.xlabel('NU_NOTA_COMP3')
plt.ylabel('NU_NOTA_COMP5')
plt.title('Gráfico de Dispersão entre NU_NOTA_COMP3 e NU_NOTA_COMP5')
plt.show()

# %% [markdown]
# ### Gráfico de linha(line plot) para NU_NOTA_COMP4 e NU_NOTA_COMP5:

# %%
plt.figure(figsize=(10, 6))

df_clean = df.dropna(subset=['NU_NOTA_COMP4', 'NU_NOTA_COMP5'])

plt.plot(df_clean['NU_NOTA_COMP4'], df_clean['NU_NOTA_COMP5'], marker='*', color='brown')
plt.xlabel('NU_NOTA_COMP4')
plt.ylabel('NU_NOTA_COMP5')

plt.title(label='Gráfico de Linha entre NU_NOTA_COMP4 e NU_NOTA_COMP5')

plt.grid(True)  # Adiciona grade ao gráfico

plt.show()
