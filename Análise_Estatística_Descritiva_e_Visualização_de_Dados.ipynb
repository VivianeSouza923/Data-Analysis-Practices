# %% [markdown]
# <a href="https://colab.research.google.com/github/VivianeSouza923/Data-Analysis-Practices/blob/main/An%C3%A1lise_Estat%C3%ADstica_Descritiva_e_Visualiza%C3%A7%C3%A3o_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Pesquisa Nacional por Amostra de Domicílios.csv - Pesquisa Nacional por Amostra de Domicílios.csv.csv')
df.head()
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo   Renda         Altura
# 0  11     0     23    8              12   800.0  1.603.807.616
# 1  11     1     23    2              12  1150.0  1.739.789.827
# 2  11     1     35    8              15   880.0  1.760.443.822
# 3  11     0     46    2               6  3500.0  1.783.157.945
# 4  11     1     47    8               9   150.0  1.690.630.954

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33183 entries, 0 to 33182
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   UF              33183 non-null  int64
#  1   Sexo            33183 non-null  int64
#  2   Idade           33183 non-null  int64
#  3   Cor             33183 non-null  int64
#  4   Anos de Estudo  33183 non-null  int64
#  5   Renda           33182 non-null  float64
#  6   Altura          33182 non-null  object
# dtypes: float64(1), int64(5), object(1)
# memory usage: 1.8+ MB

# %%
# trocando os códigos pelos significados:
# acessando a coluna sexo do dataframe, eu vou alterar os valores 0 e 1 para masculino e feminino, respectivamente. O inplace=True serve para especificar que a modificação será feita no próprio dataframe, em vez de retornar uma cópia dele com a modificação.
df['Sexo'].replace({0:'Masculino', 1: 'Feminino'}, inplace=True)
df
# Out:
#        UF       Sexo  Idade  Cor  Anos de Estudo   Renda         Altura
# 0      11  Masculino     23    8              12   800.0  1.603.807.616
# 1      11   Feminino     23    2              12  1150.0  1.739.789.827
# 2      11   Feminino     35    8              15   880.0  1.760.443.822
# 3      11  Masculino     46    2               6  3500.0  1.783.157.945
# 4      11   Feminino     47    8               9   150.0  1.690.630.954
# ...    ..        ...    ...  ...             ...     ...            ...
# 33178  31  Masculino     60    4              12  8000.0  1.649.400.782
# 33179  31  Masculino     33    8              15  2300.0  1.693.094.939
# 33180  31   Feminino     31    8              12  2000.0  1.849.360.141
# 33181  31   Feminino     52    2               9  4000.0  1.785.048.175
# 33182  31  Masculino     36    8               1     NaN            NaN
#
# [33183 rows x 7 columns]

# %%
df['UF'].replace({
    11:'Rondônia',
    12:'Acre',
    13:'Amazonas',
    14:'Roraima',
    15:'Pará',
    16:'Amapá',
    17:'Tocatins',
    21:'Maranhão',
    22:'Piauí',
    23:'Ceará',
    24:'Rio Grande do Norte',
    25:'Paraíba',
    26:'Pernambuco',
    27:'Alagoas',
    28:'Sergipe',
    29:'Bahia',
    31:'Minas Gerais',
    32:'Espírito Santo',
    33:'Rio de Janeiro',
    35:'São Paulo',
    41:'Paraná',
    42:'Santa Catarina',
    43:'Rio Grande do Sul',
    50:'Mato Grosso do Sul',
    51:'Mato Grosso',
    52:'Goiás',
    53:'Distrito Federal'

}, inplace=True)

df
# Out:
#                  UF       Sexo  Idade  Cor  Anos de Estudo   Renda  \
# 0          Rondônia  Masculino     23    8              12   800.0
# 1          Rondônia   Feminino     23    2              12  1150.0
# 2          Rondônia   Feminino     35    8              15   880.0
# 3          Rondônia  Masculino     46    2               6  3500.0
# 4          Rondônia   Feminino     47    8               9   150.0
# ...             ...        ...    ...  ...             ...     ...
# 33178  Minas Gerais  Masculino     60    4              12  8000.0
# 33179  Minas Gerais  Masculino     33    8              15  2300.0
# 33180  Minas Gerais   Feminino     31    8              12  2000.0
# 33181  Minas Gerais   Feminino     52    2               9  4000.0
# 33182  Minas Gerais  Masculino     36    8               1     NaN
#
#               Altura
# 0      1.603.807.616
# 1      1.739.789.827
# 2      1.760.443.822
# 3      1.783.157.945
# 4      1.690.630.954
# ...              ...
# ...

# %%
anos_de_estudo = {
    1:'Sem instrução e menos de 1 ano',
    2:'1 ano',
    3:'2 anos',
    4:'3 anos',
    5:'4 anos',
    6:'5 anos',
    7:'6 anos',
    8:'7 anos',
    9:'8 anos',
    10:'9 anos',
    11:'10 anos',
    12:'11 anos',
    13:'12 anos',
    14:'13 anos',
    15:'14 anos',
    16:'15 anos ou mais',
    17:'Não determinados',

}

df['Anos de Estudo'].replace(anos_de_estudo, inplace=True)
df
# Out:
#                  UF       Sexo  Idade  Cor                  Anos de Estudo  \
# 0          Rondônia  Masculino     23    8                         11 anos
# 1          Rondônia   Feminino     23    2                         11 anos
# 2          Rondônia   Feminino     35    8                         14 anos
# 3          Rondônia  Masculino     46    2                          5 anos
# 4          Rondônia   Feminino     47    8                          8 anos
# ...             ...        ...    ...  ...                             ...
# 33178  Minas Gerais  Masculino     60    4                         11 anos
# 33179  Minas Gerais  Masculino     33    8                         14 anos
# 33180  Minas Gerais   Feminino     31    8                         11 anos
# 33181  Minas Gerais   Feminino     52    2                          8 anos
# 33182  Minas Gerais  Masculino     36    8  Sem instrução e menos de 1 ano
#
#         Renda         Altura
# 0       800.0  1.603.807.616
# ...

# %%
cor = {
    0:'Indígena',
    2:'Branca',
    4:'Preta',
    6:'Amarela',
    8:'Parda',
    9:'Sem declaração'
}

df['Cor'].replace(cor, inplace=True)
df
# Out:
#                  UF       Sexo  Idade     Cor                  Anos de Estudo  \
# 0          Rondônia  Masculino     23   Parda                         11 anos
# 1          Rondônia   Feminino     23  Branca                         11 anos
# 2          Rondônia   Feminino     35   Parda                         14 anos
# 3          Rondônia  Masculino     46  Branca                          5 anos
# 4          Rondônia   Feminino     47   Parda                          8 anos
# ...             ...        ...    ...     ...                             ...
# 33178  Minas Gerais  Masculino     60   Preta                         11 anos
# 33179  Minas Gerais  Masculino     33   Parda                         14 anos
# 33180  Minas Gerais   Feminino     31   Parda                         11 anos
# 33181  Minas Gerais   Feminino     52  Branca                          8 anos
# 33182  Minas Gerais  Masculino     36   Parda  Sem instrução e menos de 1 ano
#
#         Renda         Altura
# ...

# %%
# Remover os pontos de separação de milhares e converter para números inteiros
df['Altura'] = df['Altura'].str.replace('.', '').astype(float).astype(pd.Int64Dtype())
print(df)
# Out:
#                  UF       Sexo  Idade     Cor                  Anos de Estudo  \
# 0          Rondônia  Masculino     23   Parda                         11 anos
# 1          Rondônia   Feminino     23  Branca                         11 anos
# 2          Rondônia   Feminino     35   Parda                         14 anos
# 3          Rondônia  Masculino     46  Branca                          5 anos
# 4          Rondônia   Feminino     47   Parda                          8 anos
# ...             ...        ...    ...     ...                             ...
# 33178  Minas Gerais  Masculino     60   Preta                         11 anos
# 33179  Minas Gerais  Masculino     33   Parda                         14 anos
# 33180  Minas Gerais   Feminino     31   Parda                         11 anos
# 33181  Minas Gerais   Feminino     52  Branca                          8 anos
# 33182  Minas Gerais  Masculino     36   Parda  Sem instrução e menos de 1 ano
#
#         Renda      Altura
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33183 entries, 0 to 33182
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   UF              33183 non-null  object
#  1   Sexo            33183 non-null  object
#  2   Idade           33183 non-null  int64
#  3   Cor             33183 non-null  object
#  4   Anos de Estudo  33183 non-null  object
#  5   Renda           33182 non-null  float64
#  6   Altura          33182 non-null  Int64
# dtypes: Int64(1), float64(1), int64(1), object(4)
# memory usage: 1.8+ MB

# %% [markdown]
# ## a) Calcular média, moda, mediana, amplitude, variância, desvio padrão e CV para variáveis quantitativas

# %%
# caĺculo de méddia de renda:

media = df['Renda'].mean()
media
# Out:
# 1472.5200108492556

# %%
# cálculo de mediana de rendda:

mediana = df['Renda'].median()
mediana
# Out:
# 840.0

# %%
# cálculo de moda de renda:

moda = df['Renda'].mode()
moda
# Out:
# 0    788.0
# Name: Renda, dtype: float64

# %%
# cálculo da amplitude de rendda:

amplitudde = df['Renda'].max() - df['Renda'].min()
amplitudde
# Out:
# 200000.0

# %%
# cálculo da variância de renda:

variancia = df['Renda'].var()
variancia
# Out:
# 6627920.628076694

# %%
# cálculo do desvio paddrão de renda:

desvio_padrao = df['Renda'].std()
desvio_padrao
# Out:
# 2574.4748256832295

# %%
# cálculo ddo coeficiente de variação de rendda:

coef_var = (df['Renda'].std() / df['Renda'].mean()) * 100
coef_var
# Out:
# 174.83462409440781

# %%
# cálculo da média por grupo

# para isso, uso o grupbyu
import matplotlib.pyplot as plt
plt.scatter(df['Variavel1'], df['Variavel2'])
plt.xlabel('Variavel1')
plt.ylabel('Variavel2')
plt.title('Gráfico de Dispersão entre Variavel1 e Variavel2')
plt.show()

df['Renda'].groupby(df['Sexo']).mean()
# Out:
# Sexo
# Feminino     1217.392318
# Masculino    1587.945023
# Name: Renda, dtype: float64

# %%
# cálculo da média por mais de um grupo:

df['Renda'].groupby([df['Cor'], df['Sexo']]).mean()
# Out:
# Cor       Sexo
# Amarela   Feminino     1284.555556
#           Masculino    4303.951220
# Branca    Feminino     1806.867057
#           Masculino    2259.885282
# Indígena  Feminino      814.534483
#           Masculino     896.100000
# Parda     Feminino     1058.746074
#           Masculino    1385.368534
# Preta     Feminino      961.780702
#           Masculino    1333.874778
# Name: Renda, dtype: float64

# %%
df.groupby(['UF'])['Renda'].mean().sort_values()
# Out:
# UF
# Maranhão               1019.432009
# Piauí                  1074.550784
# Sergipe                1109.111111
# Alagoas                1144.552602
# Ceará                  1255.403692
# Paraíba                1293.370487
# Rio Grande do Norte    1344.721480
# Pará                   1399.076871
# Bahia                  1429.645094
# Amazonas               1445.130100
# Acre                   1506.091782
# Pernambuco             1527.079319
# Tocatins               1771.094946
# Roraima                1783.588889
# Rondônia               1789.761223
# Amapá                  1861.353516
# Minas Gerais           3147.859971
# Name: Renda, dtype: float64

# %%
# não conseguimos aplicar a modde diretamente na groupby, portanto temos que fazer de outra forma (vide celula abaixo)
df['Renda'].groupby(df['Cor']).mode()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-8319f0716f5c> in <cell line: 2>()
#       1 # não conseguimos aplicar a modde diretamente na groupby, portanto temos que fazer de outra forma (vide celula abaixo)
# ----> 2 df['Renda'].groupby(df['Cor']).mode()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     950             return self[attr]
#     951
# --> 952         raise AttributeError(
#     953             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'mode'

# %%
# forma que consigo a moda sem dar erro por causa da combinação de groupby e mode:

# vou trauzir: estou agrupando por cor. Nesse agrupamento, eu estou iuunterssada na coluna rena, ondde eu vou aplicar uma função lambda que calcula a moda
df.groupby('Cor')['Renda'].apply(lambda x: x.mode())
# Out:
# Cor
# Amarela   0    788.0
# Branca    0    788.0
# Indígena  0      0.0
# Parda     0    788.0
# Preta     0    788.0
# Name: Renda, dtype: float64

# %% [markdown]
# ### * Variável Idade *

# %%
# cálculo de média de idade:

media_iddade = df['Idade'].mean()
media_iddade
# Out:
# 43.65584787391134

# %%
# cálculo de modda:

moda_idade = df['Idade'].mode()
moda_idade
# Out:
# 0    35
# Name: Idade, dtype: int64

# %%
# cálculo mediana:

mediana_idade = df['Idade'].median()
mediana_idade
# Out:
# 43.0

# %%
# cálculo amplitude:

amplitudde_idade = df['Idade'].max() - df['Idade'].min()
amplitudde_idade
# Out:
# 84

# %%
# cálculo variância:

variancia_idade = df['Idade'].var()
variancia_idade
# Out:
# 158.7991616756093

# %%
# cálculo desvio padrão
ddesvio_padrao_idade = df['Idade'].std()
ddesvio_padrao_idade
# Out:
# 12.601553938923933

# %%
# cálculo coeficiente de variância:

cv_idade = (df['Idade'].std() / df['Idade'].mean()) * 100
cv_idade
# Out:
# 28.865672189715045

# %% [markdown]
# ### ** Variável Altura **

# %%
# cálculoo média:

meddia_altura = df['Altura'].mean()
meddia_altura
# Out:
# 1547078783.8133326

# %%
# cálculo moda:

modda_altura = df['Altura'].mode()
modda_altura
# Out:
# 0     156812756
# 1    1692976729
# 2    1796462296
# Name: Altura, dtype: Int64

# %%
# cálculo mediana:

mediana_altura = df['Altura'].median()
mediana_altura
# Out:
# 1688688668.5

# %%
# cálculo amplitude:

amplitudde_altura = df['Altura'].max() - df[ 'Altura'].min()
amplitudde_altura
# Out:
# 2015672256

# %%
# c´alculo variância:

variancia_altura = df['Altura'].var()
variancia_altura
# Out:
# 2.184570978215765e+17

# %%
# cálculo desvio padrão:

std_altura = df['Altura'].std()
std_altura
# Out:
# 467393942.8593149

# %%
# cálculo coeficiente de variação:

cv_altura = (df['Altura'].std() / df['Altura'].mean()) * 100
cv_altura
# Out:
# 30.211385984316475

# %% [markdown]
# ## b) Construir gráficos adequados para os pares de variáveis

# %% [markdown]
# ### Gráfico de dispersão (scatter plot) para renda e idade:

# %%
plt.scatter(df['Renda'], df['Idade'], c='m')
plt.xlabel('Renda')
plt.ylabel('Idade')
plt.title('Gráfico de Dispersão entre Renda e Idade')
plt.show()

# %% [markdown]
# ### Gráfico de linha(line plot) para renda e altura

# %%
# dimensões da figura
plt.figure(figsize=(10, 6))

df_clean = df.dropna(subset=['Renda', 'Altura'])

plt.plot(df_clean['Renda'], df_clean['Altura'], marker='.', color='orange') # o marker passa a forma que terá
plt.xlabel('Renda')
plt.ylabel('Altura')

plt.title(label='Gráfico de Linha entre Renda e Altura')

plt.grid(True)  # Adiciona grade ao gráfico

plt.show()

# %% [markdown]
# ### Gráfico de dispersão (scatter plot) para iddade e altuura:

# %%
df_cleasn = df.dropna(subset=['Idade', 'Altura'])
plt.scatter(df_cleasn['Idade'], df_cleasn['Altura'], color='olive')


plt.xlabel('Idade')
plt.ylabel('Altura')
plt.title('Gráfico de Dispersão entre Idade e Altura')
plt.show()
